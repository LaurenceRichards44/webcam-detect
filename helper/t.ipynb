# %%
from network import *
from sklearn.model_selection import train_test_split

# %%
X = np.load("ann_train_val/X.npy")
Y = np.load("ann_train_val/Y.npy")

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
x_train = np.load("ann_train_val/X.npy")
y_train = np.load("ann_train_val/Y.npy")

x_test = np.load("ann_test/X.npy")
y_test = np.load("ann_test/Y.npy")

# %%
model = Network(
    layerSizes=[42,128,64,19],
    activations=["relu","relu","softmax"],
    lossName="crossentropy",
    optimizer="adam"
)
# Out:
# Layer 1: 42 → 128 (relu)
# Layer 2: 128 → 64 (relu)
# Layer 3: 64 → 19 (softmax)

# %%
model.Load("models/workingmodel.npz")
# Out:
# Layer 1: 42 → 128 (relu)
# Layer 2: 128 → 64 (relu)
# Layer 3: 64 → 19 (softmax)
# 3
# Model loaded from 'models/workingmodel.npz'

# %%
model.Train(x_train, y_train, x_test, y_test, learningRate=0.0001, epochs=3, batchSize=256)
# Out:
# Epoch 1/3: 100%|██████████| 1948/1948 [00:03<00:00, 610.96batch/s]
# Epoch 2/3: 100%|██████████| 1948/1948 [00:03<00:00, 617.22batch/s]
# Epoch 3/3: 100%|██████████| 1948/1948 [00:02<00:00, 714.04batch/s]
# losses array: [[np.float64(2.6372356708101896), np.float64(2.0595051725346907), np.float64(1.5016596296017282)]]

# %%
model.PlotLossAccuracy(legend = False, linearFit = False)

# %%
model.TrainSummary()
# Out:
# Training Summary
# ============================================================
# Run 1
# ------------------------------------------------------------
# Epoch 1     Loss=2.6372, Test Accuracy=28.43%
# Epoch 2     Loss=2.0595, Test Accuracy=50.36%
# Epoch 3     Loss=1.5017, Test Accuracy=58.56%
#
# ============================================================

# %%
model.Save("biggermodel(98)")
# Out:
# Model saved to 'models/biggermodel(98)'
